# %%
library(rtracklayer)
library(ArchR)
library(plyranges)
library(TxDb.Hsapiens.UCSC.hg38.knownGene)
library(BSgenome.Hsapiens.UCSC.hg38)
library(Organism.dplyr)
library(Homo.sapiens)
library(dplyr)

source("plotting_functions.R")

# %%
tss <- '../../data/1D_signal/refTSS_v3.3_human_coordinate.hg38.bed'
region <- GRanges(seqnames = "chr8", ranges = IRanges(126200000, 129000000))

# %%
tss <- 'refTSS_v3.3_human_coordinate.hg38.bed' #https://reftss.riken.jp/datafiles/3.3/human/refTSS_v3.3_human_coordinate.hg38.bed.gz
region <- GRanges(seqnames = "chr8", ranges = IRanges(126200000, 129000000))

# %%
bigwig1 <- import('../../data/1D_signal/ENCFF905FLR_Liver_H3K27ac_ChIP.bw', format = "BigWig")
bigwig1$RG <- "Liver H3K27ac"
bigwig2 <- import('../../data/1D_signal/ENCFF873MWG_Colon_H3K27ac_ChIP.bw', format = "BigWig")
bigwig2$RG <- "Colon H3K27ac"
bigwig <- c(bigwig1, bigwig2)

# %%
# Liver H3K27ac ChIP-seq from ENCODE https://www.encodeproject.org/files/ENCFF905FLR/@@download/ENCFF905FLR.bigWig
bigwig1 <- import('ENCFF905FLR.bigWig', format = "BigWig")
bigwig1$RG <- "Liver H3K27ac ChIP-seq"
# Colon H3K27ac ChIP-seq from ENCODE https://www.encodeproject.org/files/ENCFF873MWG/@@download/ENCFF873MWG.bigWig
bigwig2 <- import('ENCFF873MWG.bigWig', format = "BigWig")
bigwig2$RG <- "Colon H3K27ac ChIP-seq"
bigwig <- c(bigwig1, bigwig2)

# %%
p1 <- bigWig_track(bigwig_gr = bigwig, region = region, tss = tss)
# Out:
# Warning message:
# “`aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.”

# %%
p1
# Out:
# plot without title

# %%
fragment1 <- import("../../data/1D_signal/COAD_H3K27ac_1D-signal.sort.bed.gz", format = "bed")
fragment1$RG <- "COAD H3K27ac HiChIP Enrichment"
fragment2 <- import("../../data/1D_signal/LIHC_H3K27ac_1D-signal.sort.bed.gz", format = "bed")
fragment2$RG <- "LIHC H3K27ac HiChIP Enrichment"
fragment <- c(fragment1, fragment2)
# Out:
# Error in sum(score): invalid 'type' (closure) of argument
# Traceback:
#
# 1. add_groupNormFactors(fragment, tss = tss)
# 2. TSSfragment %>% group_by(RG) %>% summarise(ReadsInTSS = sum(score))
# 3. summarise(., ReadsInTSS = sum(score))
# 4. summarise.GroupedGenomicRanges(., ReadsInTSS = sum(score))
# 5. cbind(md, summarize_rng(.data, dots))
# 6. standardGeneric("cbind")
# 7. eval(quote(list(...)), env)
# 8. eval(quote(list(...)), env)
# 9. eval(quote(list(...)), env)
# 10. summarize_rng(.data, dots)
# 11. overscope_eval_update(overscope, dots, FALSE)
# 12. eval_tidy(quo, data = overscope)

# %%
# COAD H3K27ac HiChIP 1D signal bed from publication page
fragment1 <- import("COAD_H3K27ac_1D-signal.sort.bed.gz", format = "bed")
fragment1$RG <- "COAD"
# LIHC H3K27ac HiChIP 1D signal bed from publication page
fragment2 <- import("LIHC_H3K27ac_1D-signal.sort.bed.gz", format = "bed")
fragment2$RG <- "LIHC"
fragment <- c(fragment1, fragment2)

# %%
p2 <- H3K27Ac_1D_track(fragment, region = region, tss = tss)

# %%
p2
# Out:
# plot without title

# %%
hic_files_merged <- list.files("../../data/hic_files/merged", pattern = ".*hic", full.names = TRUE)
names(hic_files_merged) <- gsub("x", "", gsub("_.*", "", gsub(".*merged/", "", hic_files_merged)))

run_summary <- read.delim("../../data/190702_HiCPro_RunSummary.txt")
validPairs_merged <- run_summary$Valid_Interaction_Pairs
names(validPairs_merged) <-  gsub("x", "", gsub("_H3K27ac", "", run_summary$X))

# %%
# H3K27ac HiChIP hic files from publication page
hic_files_merged <- c("COAD_H3K27ac.allValidPairs.hic", "LIHC_H3K27ac.allValidPairs.hic")
names(hic_files_merged) <- gsub("_.*", "",hic_files_merged)

# number of valid pairs
validPairs_merged <- setNames(c(221818488, 128424571), c("COAD", "LIHC"))

# %%
p3 <- virtual4C_plot(hic_files_merged[c('COAD')]
                     , names = names(hic_files_merged[c('COAD')])
                     , res = 10000
                     , color = paletteDiscrete(values = c("COAD", "LIHC"))['COAD']
                     , norm = validPairs_merged[c('COAD')]
                     , bedpe = "../../data/loops/TCGA_Merged/COAD_H3K27ac.FitHiChIP.interactions_Q0.1_MergeNearContacts.bedpe", 
                     , region = region
                     , anchor_gene = "MYC")
# Out:
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”

# %%
p4 <- virtual4C_plot(hic_files_merged[c('LIHC')]
               , pal = paletteDiscrete(values = c("COAD", "LIHC"))
               , names = names(hic_files_merged[c('LIHC')])
               , res = 10000
               , color = paletteDiscrete(values = c("COAD", "LIHC"))['LIHC']
               , norm = validPairs_merged[c('COAD')]
               , bedpe = "../../data/loops/TCGA_Merged/LIHC_H3K27ac.FitHiChIP.interactions_Q0.1_MergeNearContacts.bedpe", 
               , region = region
               , anchor_gene = "MYC")

# %%
p5 <- plot_genes(region = region, gene_list = "MYC")
# Out:
# collapsing
#
# Warning message:
# “Returning more (or less) than 1 row per `summarise()` group was deprecated in dplyr 1.1.0.
# ℹ Please use `reframe()` instead.
# ℹ When switching from `summarise()` to `reframe()`, remember that `reframe()` always returns an ungrouped data
#   frame and adjust accordingly.”

# %%
options(repr.plot.width = 8, repr.plot.height = 12)
patchwork::wrap_plots(p1,p2,p3,p4,p5, ncol = 1, heights = c(4,4,4,4,1))
# Out:
# plot without title
